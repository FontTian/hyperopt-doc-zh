# %% [markdown]
# # 如何使用hyperopt对Lightgbm进行自动调参
#
# 之前的教程以及介绍过如何使用hyperopt对xgboost进行调参，并且已经说明了，该代码模板可以十分轻松的转移到lightgbm，或者catboost上。而本篇教程就是对原模板的一次迁移，前半部分为[教程-如何使用hyperopt对xgboost进行自动调参](https://zhuanlan.zhihu.com/p/52562126)的迁移，后半部分是对[在Hyperopt框架下使用XGboost与交叉验证](https://zhuanlan.zhihu.com/p/52562732)的迁移。
#
#
# ## 关于Hyperopt
#
# Hyperopt：是python中的一个用于"分布式异步算法组态/超参数优化"的类库。使用它我们可以拜托繁杂的超参数优化过程，自动获取最佳的超参数。广泛意义上，可以将带有超参数的模型看作是一个必然的非凸函数，因此hyperopt几乎可以稳定的获取比手工更加合理的调参结果。尤其对于调参比较复杂的模型而言，其更是能以远快于人工调参的速度同样获得远远超过人工调参的最终性能。
#
# 目前中文文档的地址由本人FontTian在2017年翻译，但是hyperopt文档本身确实写的不怎么样。所以才有了这份教程。源代码请前往[Github教程地址下载](https://github.com/FontTian/hyperopt-doc-zh/tree/master/tutorials/zh)下载。
#
#  - [中文文档地址](https://github.com/FontTian/hyperopt-doc-zh)
#  - [FontTian的博客](https://blog.csdn.net/fontthrone)
#  - [Hyperopt官方文档地址](http://hyperopt.github.io/)
#
#
# # 迁移一：自动调参
#
# ## 获取数据
# 这里我们使用UCI的红酒质量数据集，除此之外我还额外构建了两个特征。

# %%
import numpy as np
import pandas as pd
# 减少部分warning的显示
import warnings
warnings.filterwarnings("ignore")

def GetNewDataByPandas():
    wine = pd.read_csv("../data/wine.csv")
    wine['alcohol**2'] = pow(wine["alcohol"], 2)
    wine['volatileAcidity*alcohol'] = wine["alcohol"] * wine['volatile acidity']
    y = np.array(wine.quality)
    X = np.array(wine.drop("quality", axis=1))

    columns = np.array(wine.columns)

    return X, y, columns

# %% [markdown]
# ## 分割数据并转换
# 首先将数据分割为三份，一部分用于预测，训练数据则同样分成额外的两部分用于evalset参数。
#
# 同时为了加快速度和减少内存，我们将数据转换为`lightgbm`自带的数据格式。

# %%
from sklearn.model_selection import train_test_split
# Read wine quality data from file
X, y, wineNames = GetNewDataByPandas()

# split data to [[0.8,0.2],01]
x_train_all, x_predict, y_train_all, y_predict = train_test_split(X, y, test_size=0.10, random_state=100)

x_train, x_test, y_train, y_test = train_test_split(x_train_all, y_train_all, test_size=0.2, random_state=100)

import lightgbm as lgb

train_data = lgb.Dataset(data=x_train,label=y_train)
test_data = lgb.Dataset(data=x_test,label=y_test)

# %% [markdown]
# ## 定义参数空间
#
# 使用hyperopt自带的函数定义参数空间，但是因为其`randint()`方法产生的数组范围是从0开始的，所以我额外定义了一个数据转换方法，对原始参数空间进行一次转换。
#
# 关于hyperopt中定义参数区间需要使用的函数请参考：
#  - 中文地址，请点击[这里](https://github.com/FontTian/hyperopt-doc-zh/wiki/FMin)
#  - 英文地址，请点击[这里](https://github.com/FontTian/hyperopt-doc-zh/blob/master/hyperopt/doc/en/FMin.md)

# %%
from hyperopt import fmin, tpe, hp, partial

# 自定义hyperopt的参数空间
space = {"max_depth": hp.randint("max_depth", 15),
         "num_trees": hp.randint("num_trees", 300),
         'learning_rate': hp.uniform('learning_rate', 1e-3, 5e-1),
         "bagging_fraction": hp.randint("bagging_fraction", 5),
         "num_leaves": hp.randint("num_leaves", 6),
         }

def argsDict_tranform(argsDict, isPrint=False):
    argsDict["max_depth"] = argsDict["max_depth"] + 5
    argsDict['num_trees'] = argsDict['num_trees'] + 150
    argsDict["learning_rate"] = argsDict["learning_rate"] * 0.02 + 0.05
    argsDict["bagging_fraction"] = argsDict["bagging_fraction"] * 0.1 + 0.5
    argsDict["num_leaves"] = argsDict["num_leaves"] * 3 + 10
    if isPrint:
        print(argsDict)
    else:
        pass

    return argsDict

# %% [markdown]
# ## 创建模型工厂与分数获取器
#
# lightgbm模型工厂用于生产我们需要的model，而分数获取器则是为了解耦。这样在实际的测试工作中更加套用代码和修改。

# %%
from sklearn.metrics import mean_squared_error

def lightgbm_factory(argsDict):
    argsDict = argsDict_tranform(argsDict)
    
    params = {'nthread': -1,  # 进程数
              'max_depth': argsDict['max_depth'],  # 最大深度
              'num_trees': argsDict['num_trees'],  # 树的数量
              'eta': argsDict['learning_rate'],  # 学习率
              'bagging_fraction': argsDict['bagging_fraction'],  # 采样数
              'num_leaves': argsDict['num_leaves'],  # 终点节点最小样本占比的和
              'objective': 'regression',
              'feature_fraction': 0.7,  # 样本列采样
              'lambda_l1': 0,  # L1 正则化
              'lambda_l2': 0,  # L2 正则化
              'bagging_seed': 100,  # 随机种子,light中默认为100
              }
    params['metric'] = ['rmse']

    model_lgb = lgb.train(params, train_data, valid_sets=[test_data],early_stopping_rounds=100)

    return get_tranformer_score(model_lgb)

def get_tranformer_score(tranformer):
    
    model = tranformer
    prediction = model.predict(x_predict, num_iteration=model.best_iteration)
  
    return mean_squared_error(y_predict, prediction)

# %% [markdown]
# ### 调用Hyperopt开始调参
# 之后我们调用hyperopt进行自动调参即可，同时通过返回值获取最佳模型的结果。

# %%
# 开始使用hyperopt进行自动调参
algo = partial(tpe.suggest, n_startup_jobs=1)
best = fmin(lightgbm_factory, space, algo=algo, max_evals=20, pass_expr_memo_ctrl=None)
# Out:
# [1]	valid_0's rmse: 0.794347
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's rmse: 0.77769
# [3]	valid_0's rmse: 0.763884
# [4]	valid_0's rmse: 0.75142
# [5]	valid_0's rmse: 0.740089
# [6]	valid_0's rmse: 0.7286
# [7]	valid_0's rmse: 0.717008
# [8]	valid_0's rmse: 0.706617
# [9]	valid_0's rmse: 0.697946
# [10]	valid_0's rmse: 0.68893
# [11]	valid_0's rmse: 0.680814
# [12]	valid_0's rmse: 0.674323
# [13]	valid_0's rmse: 0.667275
# [14]	valid_0's rmse: 0.661204
# [15]	valid_0's rmse: 0.65623
# [16]	valid_0's rmse: 0.652134
# [17]	valid_0's rmse: 0.648408
# [18]	valid_0's rmse: 0.644887
# [19]	valid_0's rmse: 0.641335
# [20]	valid_0's rmse: 0.637457
# [21]	valid_0's rmse: 0.633712
# [22]	valid_0's rmse: 0.629942
# [23]	valid_0's rmse: 0.627541
# [24]	valid_0's rmse: 0.62445
# [25]	valid_0's rmse: 0.623151
# [26]	valid_0's rmse: 0.621391
# [27]	valid_0's rmse: 0.619288
# [28]	valid_0's rmse: 0.617023
# [29]	valid_0's rmse: 0.615039
# [30]	valid_0's rmse: 0.613805
# [31]	valid_0's rmse: 0.611538
# [32]	valid_0's rmse: 0.61008
# [33]	valid_0's rmse: 0.608697
# [34]	valid_0's rmse: 0.607879
# [35]	valid_0's rmse: 0.606498
# [36]	valid_0's rmse: 0.605272
# [37]	valid_0's rmse: 0.605625
# [38]	valid_0's rmse: 0.60513
# [39]	valid_0's rmse: 0.603598
# [40]	valid_0's rmse: 0.6026
# [41]	valid_0's rmse: 0.60121
# [42]	valid_0's rmse: 0.600149
# [43]	valid_0's rmse: 0.59925
# [44]	valid_0's rmse: 0.598655
# [45]	valid_0's rmse: 0.5976
# [46]	valid_0's rmse: 0.59721
# [47]	valid_0's rmse: 0.596152
# [48]	valid_0's rmse: 0.595162
# [49]	valid_0's rmse: 0.595083
# [50]	valid_0's rmse: 0.595079
# [51]	valid_0's rmse: 0.594403
# [52]	valid_0's rmse: 0.594288
# [53]	valid_0's rmse: 0.59332
# [54]	valid_0's rmse: 0.593049
# [55]	valid_0's rmse: 0.592423
# [56]	valid_0's rmse: 0.592405
# [57]	valid_0's rmse: 0.592585
# [58]	valid_0's rmse: 0.591396
# [59]	valid_0's rmse: 0.590682
# [60]	valid_0's rmse: 0.589877
# [61]	valid_0's rmse: 0.589038
# [62]	valid_0's rmse: 0.58893
# [63]	valid_0's rmse: 0.588195
# [64]	valid_0's rmse: 0.587031
# [65]	valid_0's rmse: 0.586291
# [66]	valid_0's rmse: 0.585534
# [67]	valid_0's rmse: 0.584345
# [68]	valid_0's rmse: 0.584462
# [69]	valid_0's rmse: 0.58417
# [70]	valid_0's rmse: 0.583917
# [71]	valid_0's rmse: 0.58378
# [72]	valid_0's rmse: 0.58339
# [73]	valid_0's rmse: 0.582518
# [74]	valid_0's rmse: 0.58255
# [75]	valid_0's rmse: 0.581847
# [76]	valid_0's rmse: 0.58112
# [77]	valid_0's rmse: 0.58146
# [78]	valid_0's rmse: 0.58114
# [79]	valid_0's rmse: 0.581217
# [80]	valid_0's rmse: 0.581101
# [81]	valid_0's rmse: 0.580847
# [82]	valid_0's rmse: 0.580522
# [83]	valid_0's rmse: 0.580448
# [84]	valid_0's rmse: 0.580237
# [85]	valid_0's rmse: 0.580299
# [86]	valid_0's rmse: 0.579902
# [87]	valid_0's rmse: 0.579682
# [88]	valid_0's rmse: 0.579398
# [89]	valid_0's rmse: 0.579072
# [90]	valid_0's rmse: 0.579385
# [91]	valid_0's rmse: 0.579076
# [92]	valid_0's rmse: 0.578985
# [93]	valid_0's rmse: 0.579092
# [94]	valid_0's rmse: 0.57889
# [95]	valid_0's rmse: 0.578707
# [96]	valid_0's rmse: 0.578764
# [97]	valid_0's rmse: 0.578649
# [98]	valid_0's rmse: 0.578304
# [99]	valid_0's rmse: 0.578421
# [100]	valid_0's rmse: 0.578496
# [101]	valid_0's rmse: 0.578006
# [102]	valid_0's rmse: 0.578434
# [103]	valid_0's rmse: 0.578152
# [104]	valid_0's rmse: 0.578027
# [105]	valid_0's rmse: 0.578303
# [106]	valid_0's rmse: 0.578633
# [107]	valid_0's rmse: 0.578587
# [108]	valid_0's rmse: 0.578742
# [109]	valid_0's rmse: 0.578379
# [110]	valid_0's rmse: 0.577915
# [111]	valid_0's rmse: 0.577532
# [112]	valid_0's rmse: 0.577078
# [113]	valid_0's rmse: 0.577043
# [114]	valid_0's rmse: 0.576775
# [115]	valid_0's rmse: 0.576591
# [116]	valid_0's rmse: 0.576016
# [117]	valid_0's rmse: 0.576062
# [118]	valid_0's rmse: 0.575825
# [119]	valid_0's rmse: 0.575657
# [120]	valid_0's rmse: 0.575414
# [121]	valid_0's rmse: 0.575429
# [122]	valid_0's rmse: 0.575852
# [123]	valid_0's rmse: 0.575523
# [124]	valid_0's rmse: 0.575556
# [125]	valid_0's rmse: 0.575064
# [126]	valid_0's rmse: 0.5751
# [127]	valid_0's rmse: 0.575128
# [128]	valid_0's rmse: 0.57477
# [129]	valid_0's rmse: 0.574569
# [130]	valid_0's rmse: 0.574515
# [131]	valid_0's rmse: 0.57403
# [132]	valid_0's rmse: 0.574068
# [133]	valid_0's rmse: 0.574178
# [134]	valid_0's rmse: 0.574163
# [135]	valid_0's rmse: 0.574151
# [136]	valid_0's rmse: 0.573724
# [137]	valid_0's rmse: 0.573691
# [138]	valid_0's rmse: 0.573263
# [139]	valid_0's rmse: 0.57281
# [140]	valid_0's rmse: 0.572547
# [141]	valid_0's rmse: 0.572038
# [142]	valid_0's rmse: 0.572352
# [143]	valid_0's rmse: 0.572382
# [144]	valid_0's rmse: 0.572113
# [145]	valid_0's rmse: 0.572378
# [146]	valid_0's rmse: 0.572013
# [147]	valid_0's rmse: 0.57247
# [148]	valid_0's rmse: 0.572246
# [149]	valid_0's rmse: 0.571998
# [150]	valid_0's rmse: 0.572301
# [151]	valid_0's rmse: 0.57185
# [152]	valid_0's rmse: 0.571456
# [153]	valid_0's rmse: 0.571509
# [154]	valid_0's rmse: 0.571591
# [155]	valid_0's rmse: 0.571404
# [156]	valid_0's rmse: 0.570872
# [157]	valid_0's rmse: 0.570789
# [158]	valid_0's rmse: 0.571278
# [159]	valid_0's rmse: 0.571151
# [160]	valid_0's rmse: 0.571355
# [161]	valid_0's rmse: 0.571596
# [162]	valid_0's rmse: 0.571549
# [163]	valid_0's rmse: 0.57177
# [164]	valid_0's rmse: 0.571859
# [165]	valid_0's rmse: 0.571763
# [166]	valid_0's rmse: 0.571656
# [167]	valid_0's rmse: 0.571747
# [168]	valid_0's rmse: 0.571907
# [169]	valid_0's rmse: 0.571973
# [170]	valid_0's rmse: 0.572291
# [171]	valid_0's rmse: 0.572414
# [172]	valid_0's rmse: 0.571983
# [173]	valid_0's rmse: 0.571865
# [174]	valid_0's rmse: 0.57131
# [175]	valid_0's rmse: 0.571114
# [176]	valid_0's rmse: 0.570814
# [177]	valid_0's rmse: 0.570467
# [178]	valid_0's rmse: 0.570022
# [179]	valid_0's rmse: 0.57025
# [180]	valid_0's rmse: 0.570529
# [181]	valid_0's rmse: 0.570371
# [182]	valid_0's rmse: 0.569698
# [183]	valid_0's rmse: 0.569695
# [184]	valid_0's rmse: 0.569717
# [185]	valid_0's rmse: 0.569563
# [186]	valid_0's rmse: 0.569158
# [187]	valid_0's rmse: 0.569276
# [188]	valid_0's rmse: 0.569146
# [189]	valid_0's rmse: 0.569561
# [190]	valid_0's rmse: 0.569249
# [191]	valid_0's rmse: 0.569343
# [192]	valid_0's rmse: 0.568868
# [193]	valid_0's rmse: 0.569028
# [194]	valid_0's rmse: 0.568968
# [195]	valid_0's rmse: 0.568846
# [196]	valid_0's rmse: 0.568854
# [197]	valid_0's rmse: 0.568841
# [198]	valid_0's rmse: 0.56834
# [199]	valid_0's rmse: 0.568305
# [200]	valid_0's rmse: 0.568157
# [201]	valid_0's rmse: 0.568199
# [202]	valid_0's rmse: 0.567913
# [203]	valid_0's rmse: 0.567665
# [204]	valid_0's rmse: 0.567359
# [205]	valid_0's rmse: 0.567566
# [206]	valid_0's rmse: 0.567156
# [207]	valid_0's rmse: 0.566881
# [208]	valid_0's rmse: 0.567062
# [209]	valid_0's rmse: 0.567336
# [210]	valid_0's rmse: 0.567297
# [211]	valid_0's rmse: 0.567763
# [212]	valid_0's rmse: 0.567499
# [213]	valid_0's rmse: 0.567151
# [214]	valid_0's rmse: 0.567548
# [215]	valid_0's rmse: 0.567448
# [216]	valid_0's rmse: 0.567206
# [217]	valid_0's rmse: 0.567226
# [218]	valid_0's rmse: 0.567564
# [219]	valid_0's rmse: 0.567521
# [220]	valid_0's rmse: 0.568002
# [221]	valid_0's rmse: 0.568248
# [222]	valid_0's rmse: 0.568681
# [223]	valid_0's rmse: 0.568836
# [224]	valid_0's rmse: 0.569066
# [225]	valid_0's rmse: 0.569131
# [226]	valid_0's rmse: 0.569358
# [227]	valid_0's rmse: 0.569505
# [228]	valid_0's rmse: 0.569504
# [229]	valid_0's rmse: 0.569851
# [230]	valid_0's rmse: 0.56975
# [231]	valid_0's rmse: 0.569683
# [232]	valid_0's rmse: 0.569546
# [233]	valid_0's rmse: 0.569687
# [234]	valid_0's rmse: 0.569465
# [235]	valid_0's rmse: 0.56919
# [236]	valid_0's rmse: 0.569285
# [237]	valid_0's rmse: 0.568959
# [238]	valid_0's rmse: 0.568905
# [239]	valid_0's rmse: 0.56881
# [240]	valid_0's rmse: 0.568796
# [241]	valid_0's rmse: 0.568846
# [242]	valid_0's rmse: 0.568857
# [243]	valid_0's rmse: 0.568643
# [244]	valid_0's rmse: 0.568579
# [245]	valid_0's rmse: 0.568896
# [246]	valid_0's rmse: 0.569071
# [247]	valid_0's rmse: 0.56937
# [248]	valid_0's rmse: 0.569315
# [249]	valid_0's rmse: 0.569229
# [250]	valid_0's rmse: 0.569082
# [251]	valid_0's rmse: 0.569244
# [252]	valid_0's rmse: 0.569349
# [253]	valid_0's rmse: 0.56946
# [254]	valid_0's rmse: 0.569023
# [255]	valid_0's rmse: 0.56892
# [256]	valid_0's rmse: 0.56884
# [257]	valid_0's rmse: 0.568868
# [258]	valid_0's rmse: 0.568606
# [259]	valid_0's rmse: 0.568701
# [260]	valid_0's rmse: 0.56847
# [261]	valid_0's rmse: 0.568588
# [262]	valid_0's rmse: 0.568555
# [263]	valid_0's rmse: 0.568337
# [264]	valid_0's rmse: 0.568289
# [265]	valid_0's rmse: 0.56819
# [266]	valid_0's rmse: 0.568501
# [267]	valid_0's rmse: 0.56855
# [268]	valid_0's rmse: 0.56851
# [269]	valid_0's rmse: 0.568484
# [270]	valid_0's rmse: 0.568463
# [271]	valid_0's rmse: 0.568554
# [272]	valid_0's rmse: 0.568543
# [273]	valid_0's rmse: 0.568557
# [274]	valid_0's rmse: 0.568487
# [275]	valid_0's rmse: 0.568304
# [276]	valid_0's rmse: 0.567987
# [277]	valid_0's rmse: 0.568065
# [278]	valid_0's rmse: 0.568232
# [279]	valid_0's rmse: 0.568494
# [280]	valid_0's rmse: 0.568842
# [281]	valid_0's rmse: 0.568601
# [282]	valid_0's rmse: 0.568606
# [283]	valid_0's rmse: 0.568431
# [284]	valid_0's rmse: 0.568623
# [285]	valid_0's rmse: 0.568666
# [286]	valid_0's rmse: 0.568452
# [287]	valid_0's rmse: 0.568251
# [288]	valid_0's rmse: 0.568223
# [289]	valid_0's rmse: 0.568018
# [290]	valid_0's rmse: 0.567628
# [291]	valid_0's rmse: 0.567735
# [292]	valid_0's rmse: 0.567614
# [293]	valid_0's rmse: 0.567286
# [294]	valid_0's rmse: 0.566963
# [295]	valid_0's rmse: 0.566755
# [296]	valid_0's rmse: 0.566825
# [297]	valid_0's rmse: 0.566666
# [298]	valid_0's rmse: 0.56648
# [299]	valid_0's rmse: 0.56666
# [300]	valid_0's rmse: 0.56675
# [301]	valid_0's rmse: 0.566851
# [302]	valid_0's rmse: 0.566694
# [303]	valid_0's rmse: 0.567002
# [304]	valid_0's rmse: 0.567188
# [305]	valid_0's rmse: 0.567371
# [306]	valid_0's rmse: 0.567002
# [307]	valid_0's rmse: 0.567193
# [308]	valid_0's rmse: 0.566994
# [309]	valid_0's rmse: 0.56693
# [310]	valid_0's rmse: 0.566921
# [311]	valid_0's rmse: 0.566742
# [312]	valid_0's rmse: 0.567042
# [313]	valid_0's rmse: 0.566926
# [314]	valid_0's rmse: 0.566842
# [315]	valid_0's rmse: 0.566728
# [316]	valid_0's rmse: 0.567142
# [317]	valid_0's rmse: 0.567019
# [318]	valid_0's rmse: 0.567177
# [319]	valid_0's rmse: 0.567298
# [320]	valid_0's rmse: 0.567553
# [321]	valid_0's rmse: 0.567293
# [322]	valid_0's rmse: 0.567346
# [323]	valid_0's rmse: 0.567179
# [324]	valid_0's rmse: 0.567052
# [325]	valid_0's rmse: 0.567033
# [326]	valid_0's rmse: 0.566985
# [327]	valid_0's rmse: 0.56688
# [328]	valid_0's rmse: 0.566808
# [329]	valid_0's rmse: 0.566697
# [330]	valid_0's rmse: 0.566465
# [331]	valid_0's rmse: 0.566366
# Did not meet early stopping. Best iteration is:
# [331]	valid_0's rmse: 0.566366
# [1]	valid_0's rmse: 0.79443
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's rmse: 0.77784
# [3]	valid_0's rmse: 0.764085
# [4]	valid_0's rmse: 0.751663
# [5]	valid_0's rmse: 0.740246
# [6]	valid_0's rmse: 0.727889
# [7]	valid_0's rmse: 0.717706
# [8]	valid_0's rmse: 0.709231
# [9]	valid_0's rmse: 0.701627
# [10]	valid_0's rmse: 0.692086
# [11]	valid_0's rmse: 0.684837
# [12]	valid_0's rmse: 0.677142
# [13]	valid_0's rmse: 0.670849
# [14]	valid_0's rmse: 0.665174
# [15]	valid_0's rmse: 0.659712
# [16]	valid_0's rmse: 0.655857
# [17]	valid_0's rmse: 0.651478
# [18]	valid_0's rmse: 0.646746
# [19]	valid_0's rmse: 0.6429
# [20]	valid_0's rmse: 0.638988
# [21]	valid_0's rmse: 0.635124
# [22]	valid_0's rmse: 0.631788
# [23]	valid_0's rmse: 0.629573
# [24]	valid_0's rmse: 0.626643
# [25]	valid_0's rmse: 0.623526
# [26]	valid_0's rmse: 0.620982
# [27]	valid_0's rmse: 0.618589
# [28]	valid_0's rmse: 0.616363
# [29]	valid_0's rmse: 0.615399
# [30]	valid_0's rmse: 0.613821
# [31]	valid_0's rmse: 0.612165
# [32]	valid_0's rmse: 0.611217
# [33]	valid_0's rmse: 0.609807
# [34]	valid_0's rmse: 0.609302
# [35]	valid_0's rmse: 0.608845
# [36]	valid_0's rmse: 0.608413
# [37]	valid_0's rmse: 0.607121
# [38]	valid_0's rmse: 0.606526
# [39]	valid_0's rmse: 0.605527
# [40]	valid_0's rmse: 0.60441
# [41]	valid_0's rmse: 0.602696
# [42]	valid_0's rmse: 0.602069
# [43]	valid_0's rmse: 0.601915
# [44]	valid_0's rmse: 0.601042
# [45]	valid_0's rmse: 0.60042
# [46]	valid_0's rmse: 0.59998
# [47]	valid_0's rmse: 0.599396
# [48]	valid_0's rmse: 0.599701
# [49]	valid_0's rmse: 0.599452
# [50]	valid_0's rmse: 0.598976
# [51]	valid_0's rmse: 0.598072
# [52]	valid_0's rmse: 0.597279
# [53]	valid_0's rmse: 0.596673
# [54]	valid_0's rmse: 0.596397
# [55]	valid_0's rmse: 0.596206
# [56]	valid_0's rmse: 0.596379
# [57]	valid_0's rmse: 0.595662
# [58]	valid_0's rmse: 0.595555
# [59]	valid_0's rmse: 0.594747
# [60]	valid_0's rmse: 0.594787
# [61]	valid_0's rmse: 0.594529
# [62]	valid_0's rmse: 0.59461
# [63]	valid_0's rmse: 0.594157
# [64]	valid_0's rmse: 0.594028
# [65]	valid_0's rmse: 0.593665
# [66]	valid_0's rmse: 0.593722
# [67]	valid_0's rmse: 0.591643
# [68]	valid_0's rmse: 0.591758
# [69]	valid_0's rmse: 0.590854
# ...
# [90]	valid_0's rmse: 0.575113
# [91]	valid_0's rmse: 0.574816
# [92]	valid_0's rmse: 0.575146
# [93]	valid_0's rmse: 0.575094
# [94]	valid_0's rmse: 0.575158
# [95]	valid_0's rmse: 0.57526
# [96]	valid_0's rmse: 0.574974
# [97]	valid_0's rmse: 0.575102
# [98]	valid_0's rmse: 0.574922
# [99]	valid_0's rmse: 0.575032
# [100]	valid_0's rmse: 0.574887
# [101]	valid_0's rmse: 0.574676
# [102]	valid_0's rmse: 0.574819
# [103]	valid_0's rmse: 0.574616
# [104]	valid_0's rmse: 0.574412
# [105]	valid_0's rmse: 0.574462
# [106]	valid_0's rmse: 0.574654
# [107]	valid_0's rmse: 0.574043
# [108]	valid_0's rmse: 0.574077
# [109]	valid_0's rmse: 0.573663
# [110]	valid_0's rmse: 0.573488
# [111]	valid_0's rmse: 0.573037
# [112]	valid_0's rmse: 0.572955
# [113]	valid_0's rmse: 0.572548
# [114]	valid_0's rmse: 0.572099
# [115]	valid_0's rmse: 0.571714
# [116]	valid_0's rmse: 0.571389
# [117]	valid_0's rmse: 0.571717
# [118]	valid_0's rmse: 0.571641
# [119]	valid_0's rmse: 0.571644
# [120]	valid_0's rmse: 0.570896
# [121]	valid_0's rmse: 0.570595
# [122]	valid_0's rmse: 0.570508
# [123]	valid_0's rmse: 0.570866
# [124]	valid_0's rmse: 0.570926
# [125]	valid_0's rmse: 0.570721
# [126]	valid_0's rmse: 0.570478
# [127]	valid_0's rmse: 0.570593
# [128]	valid_0's rmse: 0.571252
# [129]	valid_0's rmse: 0.571488
# [130]	valid_0's rmse: 0.571547
# [131]	valid_0's rmse: 0.571132
# [132]	valid_0's rmse: 0.57063
# [133]	valid_0's rmse: 0.570647
# [134]	valid_0's rmse: 0.570466
# [135]	valid_0's rmse: 0.570238
# [136]	valid_0's rmse: 0.570067
# [137]	valid_0's rmse: 0.569934
# [138]	valid_0's rmse: 0.569536
# [139]	valid_0's rmse: 0.569853
# [140]	valid_0's rmse: 0.569888
# [141]	valid_0's rmse: 0.569647
# [142]	valid_0's rmse: 0.569987
# [143]	valid_0's rmse: 0.570128
# [144]	valid_0's rmse: 0.569958
# [145]	valid_0's rmse: 0.569709
# [146]	valid_0's rmse: 0.569223
# [147]	valid_0's rmse: 0.569001
# [148]	valid_0's rmse: 0.568705
# [149]	valid_0's rmse: 0.568642
# [150]	valid_0's rmse: 0.568778
# [151]	valid_0's rmse: 0.568362
# [152]	valid_0's rmse: 0.568213
# [153]	valid_0's rmse: 0.568125
# [154]	valid_0's rmse: 0.568051
# [155]	valid_0's rmse: 0.56827
# [156]	valid_0's rmse: 0.568333
# [157]	valid_0's rmse: 0.568698
# [158]	valid_0's rmse: 0.568593
# [159]	valid_0's rmse: 0.568634
# [160]	valid_0's rmse: 0.568236
# [161]	valid_0's rmse: 0.56818
# [162]	valid_0's rmse: 0.568208
# [163]	valid_0's rmse: 0.568167
# [164]	valid_0's rmse: 0.567827
# [165]	valid_0's rmse: 0.567597
# [166]	valid_0's rmse: 0.567436
# [167]	valid_0's rmse: 0.567123
# [168]	valid_0's rmse: 0.567085
# [169]	valid_0's rmse: 0.566663
# [170]	valid_0's rmse: 0.566674
# [171]	valid_0's rmse: 0.566667
# [172]	valid_0's rmse: 0.566417
# [173]	valid_0's rmse: 0.566477
# [174]	valid_0's rmse: 0.566732
# [175]	valid_0's rmse: 0.566303
# [176]	valid_0's rmse: 0.566107
# [177]	valid_0's rmse: 0.566237
# [178]	valid_0's rmse: 0.566122
# [179]	valid_0's rmse: 0.565854
# [180]	valid_0's rmse: 0.565745
# [181]	valid_0's rmse: 0.565823
# [182]	valid_0's rmse: 0.566296
# [183]	valid_0's rmse: 0.56632
# [184]	valid_0's rmse: 0.566283
# [185]	valid_0's rmse: 0.565823
# [186]	valid_0's rmse: 0.565906
# [187]	valid_0's rmse: 0.56571
# [188]	valid_0's rmse: 0.565808
# [189]	valid_0's rmse: 0.565549
# [190]	valid_0's rmse: 0.565513
# [191]	valid_0's rmse: 0.565769
# [192]	valid_0's rmse: 0.565522
# [193]	valid_0's rmse: 0.565461
# [194]	valid_0's rmse: 0.56554
# [195]	valid_0's rmse: 0.565253
# [196]	valid_0's rmse: 0.564882
# [197]	valid_0's rmse: 0.565025
# [198]	valid_0's rmse: 0.565165
# [199]	valid_0's rmse: 0.565491
# [200]	valid_0's rmse: 0.565217
# [201]	valid_0's rmse: 0.565033
# [202]	valid_0's rmse: 0.56495
# [203]	valid_0's rmse: 0.564566
# [204]	valid_0's rmse: 0.56428
# [205]	valid_0's rmse: 0.564044
# [206]	valid_0's rmse: 0.564338
# [207]	valid_0's rmse: 0.5646
# [208]	valid_0's rmse: 0.564521
# [209]	valid_0's rmse: 0.564618
# [210]	valid_0's rmse: 0.56462
# [211]	valid_0's rmse: 0.564229
# [212]	valid_0's rmse: 0.563938
# [213]	valid_0's rmse: 0.564174
# [214]	valid_0's rmse: 0.564173
# [215]	valid_0's rmse: 0.564181
# [216]	valid_0's rmse: 0.564148
# [217]	valid_0's rmse: 0.564085
# [218]	valid_0's rmse: 0.564238
# [337]	valid_0's rmse: 0.561529
# [338]	valid_0's rmse: 0.561566
# [339]	valid_0's rmse: 0.561345
# Did not meet early stopping. Best iteration is:
# [335]	valid_0's rmse: 0.56129
# 100%|███████████████████████████████████████████████████| 20/20 [00:47<00:00,  2.67s/it, best loss: 0.3479636167693306]

# %% [markdown]
# ## 展示结果
# 展示我们获取的最佳参数，以及该模型在训练集上的最终表现，如果想要使用交叉验证请参考其他教程。

# %%
RMSE = lightgbm_factory(best)
print('best :', best)
print('best param after transform :')
argsDict_tranform(best,isPrint=True)
print('rmse of the best lightgbm:', np.sqrt(RMSE))
# Out:
# [1]	valid_0's rmse: 0.794999
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's rmse: 0.778944
# [3]	valid_0's rmse: 0.765608
# [4]	valid_0's rmse: 0.752206
# [5]	valid_0's rmse: 0.740275
# [6]	valid_0's rmse: 0.728674
# [7]	valid_0's rmse: 0.718865
# [8]	valid_0's rmse: 0.709737
# [9]	valid_0's rmse: 0.700973
# [10]	valid_0's rmse: 0.691467
# [11]	valid_0's rmse: 0.683605
# [12]	valid_0's rmse: 0.67624
# [13]	valid_0's rmse: 0.670105
# [14]	valid_0's rmse: 0.664421
# [15]	valid_0's rmse: 0.659138
# [16]	valid_0's rmse: 0.653748
# [17]	valid_0's rmse: 0.649132
# [18]	valid_0's rmse: 0.644244
# [19]	valid_0's rmse: 0.639679
# [20]	valid_0's rmse: 0.635586
# [21]	valid_0's rmse: 0.632486
# [22]	valid_0's rmse: 0.628948
# [23]	valid_0's rmse: 0.625358
# [24]	valid_0's rmse: 0.623032
# [25]	valid_0's rmse: 0.620973
# [26]	valid_0's rmse: 0.617843
# [27]	valid_0's rmse: 0.616219
# [28]	valid_0's rmse: 0.613379
# [29]	valid_0's rmse: 0.611636
# [30]	valid_0's rmse: 0.610147
# [31]	valid_0's rmse: 0.608311
# [32]	valid_0's rmse: 0.607247
# [33]	valid_0's rmse: 0.605552
# [34]	valid_0's rmse: 0.604865
# [35]	valid_0's rmse: 0.60409
# [36]	valid_0's rmse: 0.603146
# [37]	valid_0's rmse: 0.602337
# [38]	valid_0's rmse: 0.601747
# [39]	valid_0's rmse: 0.600714
# [40]	valid_0's rmse: 0.599587
# [41]	valid_0's rmse: 0.598855
# [42]	valid_0's rmse: 0.598216
# [43]	valid_0's rmse: 0.597322
# [44]	valid_0's rmse: 0.597359
# [45]	valid_0's rmse: 0.597303
# [46]	valid_0's rmse: 0.598109
# [47]	valid_0's rmse: 0.596863
# [48]	valid_0's rmse: 0.595837
# [49]	valid_0's rmse: 0.595039
# [50]	valid_0's rmse: 0.594096
# [51]	valid_0's rmse: 0.593369
# [52]	valid_0's rmse: 0.592361
# [53]	valid_0's rmse: 0.592145
# [54]	valid_0's rmse: 0.591212
# [55]	valid_0's rmse: 0.589961
# [56]	valid_0's rmse: 0.589744
# [57]	valid_0's rmse: 0.589136
# [58]	valid_0's rmse: 0.589266
# [59]	valid_0's rmse: 0.588241
# [60]	valid_0's rmse: 0.588581
# [61]	valid_0's rmse: 0.587822
# [62]	valid_0's rmse: 0.587866
# [63]	valid_0's rmse: 0.587832
# [64]	valid_0's rmse: 0.587994
# [65]	valid_0's rmse: 0.587068
# [66]	valid_0's rmse: 0.58746
# [67]	valid_0's rmse: 0.586388
# [68]	valid_0's rmse: 0.58606
# [69]	valid_0's rmse: 0.586009
# [70]	valid_0's rmse: 0.585987
# [71]	valid_0's rmse: 0.585551
# [72]	valid_0's rmse: 0.585685
# [73]	valid_0's rmse: 0.585577
# [74]	valid_0's rmse: 0.585402
# [75]	valid_0's rmse: 0.584696
# [76]	valid_0's rmse: 0.584336
# [77]	valid_0's rmse: 0.584155
# [78]	valid_0's rmse: 0.58409
# [79]	valid_0's rmse: 0.583641
# [80]	valid_0's rmse: 0.583367
# [81]	valid_0's rmse: 0.58318
# [82]	valid_0's rmse: 0.582421
# [83]	valid_0's rmse: 0.582562
# [84]	valid_0's rmse: 0.582032
# [85]	valid_0's rmse: 0.582408
# [86]	valid_0's rmse: 0.582418
# [87]	valid_0's rmse: 0.582014
# [88]	valid_0's rmse: 0.581512
# [89]	valid_0's rmse: 0.581523
# [90]	valid_0's rmse: 0.580251
# [91]	valid_0's rmse: 0.579261
# [92]	valid_0's rmse: 0.579611
# [93]	valid_0's rmse: 0.579326
# [94]	valid_0's rmse: 0.578555
# [95]	valid_0's rmse: 0.578688
# [96]	valid_0's rmse: 0.578772
# [97]	valid_0's rmse: 0.578846
# [98]	valid_0's rmse: 0.578606
# [99]	valid_0's rmse: 0.578454
# [100]	valid_0's rmse: 0.577528
# [101]	valid_0's rmse: 0.577183
# [102]	valid_0's rmse: 0.577216
# [103]	valid_0's rmse: 0.576761
# [104]	valid_0's rmse: 0.576706
# [105]	valid_0's rmse: 0.576681
# [106]	valid_0's rmse: 0.576564
# [107]	valid_0's rmse: 0.576521
# [108]	valid_0's rmse: 0.576515
# [109]	valid_0's rmse: 0.576701
# [110]	valid_0's rmse: 0.576475
# [111]	valid_0's rmse: 0.575944
# [112]	valid_0's rmse: 0.576052
# [113]	valid_0's rmse: 0.576413
# [114]	valid_0's rmse: 0.575911
# [115]	valid_0's rmse: 0.575548
# [116]	valid_0's rmse: 0.575796
# [117]	valid_0's rmse: 0.575914
# [118]	valid_0's rmse: 0.57638
# [119]	valid_0's rmse: 0.576536
# [120]	valid_0's rmse: 0.57624
# [121]	valid_0's rmse: 0.575778
# [122]	valid_0's rmse: 0.575351
# [123]	valid_0's rmse: 0.575424
# [124]	valid_0's rmse: 0.575559
# [125]	valid_0's rmse: 0.575763
# [126]	valid_0's rmse: 0.575468
# [127]	valid_0's rmse: 0.575412
# [128]	valid_0's rmse: 0.575215
# [129]	valid_0's rmse: 0.575225
# [130]	valid_0's rmse: 0.574503
# [131]	valid_0's rmse: 0.574108
# [132]	valid_0's rmse: 0.573964
# [133]	valid_0's rmse: 0.573846
# [134]	valid_0's rmse: 0.573502
# [135]	valid_0's rmse: 0.573502
# [136]	valid_0's rmse: 0.573178
# [137]	valid_0's rmse: 0.573115
# [138]	valid_0's rmse: 0.573258
# [139]	valid_0's rmse: 0.573066
# [140]	valid_0's rmse: 0.573003
# [141]	valid_0's rmse: 0.572734
# [142]	valid_0's rmse: 0.572832
# [143]	valid_0's rmse: 0.57259
# [144]	valid_0's rmse: 0.571981
# [145]	valid_0's rmse: 0.571958
# [146]	valid_0's rmse: 0.571831
# [147]	valid_0's rmse: 0.571277
# [148]	valid_0's rmse: 0.570935
# [149]	valid_0's rmse: 0.57089
# [150]	valid_0's rmse: 0.570778
# [151]	valid_0's rmse: 0.570719
# [152]	valid_0's rmse: 0.570787
# [153]	valid_0's rmse: 0.571153
# [154]	valid_0's rmse: 0.571314
# [155]	valid_0's rmse: 0.571161
# [156]	valid_0's rmse: 0.570815
# [157]	valid_0's rmse: 0.570834
# [158]	valid_0's rmse: 0.571093
# [159]	valid_0's rmse: 0.571098
# [160]	valid_0's rmse: 0.571421
# [161]	valid_0's rmse: 0.571546
# [162]	valid_0's rmse: 0.571392
# [163]	valid_0's rmse: 0.571548
# [164]	valid_0's rmse: 0.571376
# [165]	valid_0's rmse: 0.571557
# [166]	valid_0's rmse: 0.571295
# [167]	valid_0's rmse: 0.570797
# [168]	valid_0's rmse: 0.571012
# [169]	valid_0's rmse: 0.571095
# [170]	valid_0's rmse: 0.570866
# [171]	valid_0's rmse: 0.570804
# [172]	valid_0's rmse: 0.570478
# [173]	valid_0's rmse: 0.570483
# [174]	valid_0's rmse: 0.570486
# [175]	valid_0's rmse: 0.57068
# [176]	valid_0's rmse: 0.570537
# [177]	valid_0's rmse: 0.570341
# [178]	valid_0's rmse: 0.570415
# [179]	valid_0's rmse: 0.570345
# [180]	valid_0's rmse: 0.570498
# [181]	valid_0's rmse: 0.570188
# [182]	valid_0's rmse: 0.570436
# [183]	valid_0's rmse: 0.570169
# [184]	valid_0's rmse: 0.570527
# [185]	valid_0's rmse: 0.570661
# [186]	valid_0's rmse: 0.570863
# [187]	valid_0's rmse: 0.57069
# [188]	valid_0's rmse: 0.57098
# [189]	valid_0's rmse: 0.571066
# [190]	valid_0's rmse: 0.571313
# [191]	valid_0's rmse: 0.570772
# [192]	valid_0's rmse: 0.570547
# [193]	valid_0's rmse: 0.570483
# [194]	valid_0's rmse: 0.570181
# [195]	valid_0's rmse: 0.569861
# [196]	valid_0's rmse: 0.569598
# [197]	valid_0's rmse: 0.569816
# [198]	valid_0's rmse: 0.570027
# [199]	valid_0's rmse: 0.569899
# [200]	valid_0's rmse: 0.569721
# [201]	valid_0's rmse: 0.569757
# [202]	valid_0's rmse: 0.569621
# [203]	valid_0's rmse: 0.569605
# [204]	valid_0's rmse: 0.569535
# [205]	valid_0's rmse: 0.569218
# [206]	valid_0's rmse: 0.569333
# [207]	valid_0's rmse: 0.569204
# Did not meet early stopping. Best iteration is:
# [207]	valid_0's rmse: 0.569204
# best : {'max_depth': 15, 'num_leaves': 25, 'learning_rate': 0.0501181770650231, 'num_trees': 207, 'bagging_fraction': 0.9}
# best param after transform :
# {'max_depth': 20, 'num_leaves': 85, 'learning_rate': 0.051002363541300465, 'num_trees': 357, 'bagging_fraction': 0.59}
# rmse of the best lightgbm: 0.589884409667971

# %% [markdown]
# # 迁移二-交叉验证
# ## 说明
#
# 其实本部分与之前的一样重点依旧在于Hyperopt与Lightgbm参数传入上的一个冲突，不过解决方案很简单，先构建带有Hyperopt参数空间的模型，然后再从构建的模型中获取参数。其实这点xgboost，hyperopt，catboost三个模型的解决方案都一样。catboost自带的教程中也有这种解决方案。只不过catboost自带的教程不和lightgbm与xgboost一样在自己的原项目里，而是在原账号下又额外开了个Github项目，导致不太容易发现。实际上我也是最近在写这个的时候，才发现catboost原来是自带教程的。也正因为如此，本系列教程就不再往catboost上迁移代码了。请自行参考[catboost自带的教程](https://github.com/catboost/tutorials)
#
# ## 使用CV方法进行交叉验证
#
# sklearn部分过于简单，本处将不再做迁移。如有需要请自行迁移。

# %%
import hyperopt

train_all_data = lgb.Dataset(data=x_train_all,label=y_train_all)

def hyperopt_objective(params):
    
    model = lgb.LGBMRegressor(
        num_leaves=31,
        max_depth=int(params['max_depth']) + 5,
        learning_rate=params['learning_rate'],
        objective='regression',
        eval_metric='rmse',
        nthread=-1,
    )
     
    num_round = 10
    res = lgb.cv(model.get_params(),train_all_data, num_round, nfold=5, metrics='rmse',early_stopping_rounds=10)
    
    return min(res['rmse-mean']) # as hyperopt minimises

# %%
from numpy.random import RandomState

params_space = {
    'max_depth': hyperopt.hp.randint('max_depth', 6),
    'learning_rate': hyperopt.hp.uniform('learning_rate', 1e-3, 5e-1),
}

trials = hyperopt.Trials()

best = hyperopt.fmin(
    hyperopt_objective,
    space=params_space,
    algo=hyperopt.tpe.suggest,
    max_evals=50,
    trials=trials,
    rstate=RandomState(123)
)

print("\n展示hyperopt获取的最佳结果，但是要注意的是我们对hyperopt最初的取值范围做过一次转换")
print(best)
# Out:
# 100%|████████████████████████████████████████████████████| 50/50 [00:15<00:00,  4.09it/s, best loss: 0.607515615576009]
#
# 展示hyperopt获取的最佳结果，但是要注意的是我们对hyperopt最初的取值范围做过一次转换
# {'max_depth': 5, 'learning_rate': 0.059356676015000595}

# %% [markdown]
# ## 额外的：主站迁移说明
#
# 本文作者FontTian，从2018年12月18日起，技术博客主站将由CSDN转到知乎，同时也会做内容分级：主要内容将发布在知乎，CSDN会同步迁移。CSDN会一些知乎没有的内容如一些相对简单的内容，或者草稿，心得感悟等。知乎主要发重点内容，以质量为主。而文章链接将默认为知乎链接，部分CSDN专有的除外。
#
#  - [CSDN博客地址](https://blog.csdn.net/FontThrone)
#  - [知乎主页](https://www.zhihu.com/people/fonttian/posts)
